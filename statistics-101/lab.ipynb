# %%
output_transformations("(5, 25) (2, 16) (4, 9) (7, 4) (12, 36)", model="sqrt_y")
# Out:
# --- Transformed Data: Linear (Original) ---
# (5.0000, 25.0000) (2.0000, 16.0000) (4.0000, 9.0000) (7.0000, 4.0000) (12.0000, 36.0000)
# ------------------------------
# '(5.0000, 25.0000) (2.0000, 16.0000) (4.0000, 9.0000) (7.0000, 4.0000) (12.0000, 36.0000)'
